# %%
from pyfoma import FST, Paradigm
from pyfoma.fst import State

from pyfoma import Paradigm

# %%
fst = FST.re("abc")
fst.view()

# %%
fst.trim()
fst.view()

# %%
fst.states.add(State(name="4"))
fst.view()

# %%
from pyfoma.algorithms import filtered_accessible

filtered_accessible(fst).view()

# %%
import pyfoma.algorithms as alg
alg.filtered_accessible(fst)

# %%
FST(label=("hi",)).view()

# %%
fst.trim()
fst.view()

# %%
help(FST.trim)
# Out:
# Help on function trim in module pyfoma.algorithms:
#
# trim(self: 'FST')
#     Returns a new FST, removing states that aren't both accessible and coaccessible.

# %%
fst.trim()

# %%
FST.re("$^ignore(a)").view()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 FST.re("$^ignore(a)").view()
#
# File ~/miniforge3/lib/python3.10/site-packages/pyfoma/fst.py:91, in FST.regex(cls, regularexpression, defined, functions)
#      82 """Compile a regular expression and return the resulting FST.
#      83    Keyword arguments:
#      84    defined -- a dictionary of defined FSTs that the compiler can access whenever
#    (...)
#      87                is referenced in the regex, e.g. $^myfunc(...)
#      88 """
#      89 import pyfoma.private.regexparse as regexparse
# ---> 91 myregex = regexparse.RegexParse(regularexpression, defined, functions)
#      92 return myregex.compiled
#
# File ~/miniforge3/lib/python3.10/site-packages/pyfoma/private/regexparse.py:42, in RegexParse.__init__(self, regularexpression, defined, functions)
# ...

# %%
FST.trim
