# %%
from pyfoma import FST
from pyfoma.fst import State

# %%
fst = FST.re("abc")
fst.view()

# %%
fst.trim().view()

# %%
import pyfoma.algorithms as alg
alg.filtered_accessible(fst).view()

# %%
help(FST.trim)
# Out:
# Help on function trim in module pyfoma:
#
# trim(self: 'FST')
#     Mutates the FST, removing states that aren't both accessible and coaccessible.

# %%
fst.trim()
fst.view()

# %%
help(FST.rlg)

# %%
fst.trim()

# %%
FST.re("$^ignore(a)").view()

# %%
from pyfoma.algorithms import trimmed

trimmed(

# %%
trimmed(FST())

# %%
import re

help(FST.re)

# %%
FST.re.__func__.__doc__ = "hello"
help(FST.re)
