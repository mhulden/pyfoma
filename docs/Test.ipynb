# %%
from pyfoma import FST
from pyfoma.fst import State

# %%
fst = FST.re("abc")
fst.view()

# %%
fst.states.add(State(name="4"))
fst.view()

# %%
fst.trim().view()
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/milesper/miniforge3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3378, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/1y/v6m6qm2d3p52jn2sv6smp5cr0000gn/T/ipykernel_41863/2265827418.py", line 1, in <module>
#     fst.trim().view()
#   File "/Users/milesper/miniforge3/lib/python3.10/site-packages/pyfoma/__init__.py", line 27, in <lambda>
# TypeError: product() missing 1 required positional argument: 'fst2'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/milesper/miniforge3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 1997, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
# ...

# %%
import pyfoma.algorithms as alg
alg.filtered_accessible(fst)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [4], line 2
#       1 import pyfoma.algorithms as alg
# ----> 2 alg.filtered_accessible(fst)
#
# NameError: name 'fst' is not defined

# %%
help(FST.scc)
# Out:
# Help on function scc in module pyfoma:
#
# scc(self: 'FST') -> set
#     Calculate the strongly connected components of an FST.
#
#     This is a basic implementation of Tarjan's (1972) algorithm.
#     Tarjan, R. E. (1972), "Depth-first search and linear graph algorithms",
#     SIAM Journal on Computing, 1 (2): 146–160.
#
#     Returns a set of frozensets of states, one frozenset for each SCC.

# %%
fst.trim()
fst.view()

# %%
help(FST.rlg)

# %%
fst.trim()

# %%
FST.re("$^ignore(a)").view()

# %%
from pyfoma.algorithms import trimmed

trimmed(

# %%
trimmed(FST())

# %%
import re

help(FST.re)

# %%
FST.re.__func__.__doc__ = "hello"
help(FST.re)
